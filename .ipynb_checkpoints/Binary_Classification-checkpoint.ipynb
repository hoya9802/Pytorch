# %%
import torch

# %% [markdown]
# ## STEP 1. Make data

# %%
# choose the dataset you want
# case 1
# N = 20
# random0 = torch.randn(int(N/2), 1)
# random5 = torch.randn(int(N/2), 1) + 5
# class1_data = torch.hstack([random0, random5])
# class2_data = torch.hstack([random5, random0])

# class1_label = torch.ones(int(N/2),1)
# class2_label = torch.zeros(int(N/2),1)
# x = torch.vstack([class1_data, class2_data])
# y = torch.vstack([class1_label, class2_label])

# case 2
N = 100
radius1=0.3+0.05*torch.randn(int(N/2),1)
radius2=1+0.01*torch.randn(int(N/2),1)
theta1=2*torch.pi*torch.rand(int(N/2),1)-torch.pi
theta2=2*torch.pi*torch.rand(int(N/2),1)-torch.pi
class1_data=torch.hstack([radius1*torch.cos(theta1), radius1*torch.sin(theta1)])
class2_data=torch.hstack([radius2*torch.cos(theta2), radius2*torch.sin(theta2)])
class1_label=torch.ones(int(N/2),1)
class2_label=torch.zeros(int(N/2),1)
x = torch.vstack([class1_data, class2_data])
y = torch.vstack([class1_label, class2_label])

# %%
import matplotlib.pyplot as plt
plt.plot(class1_data[:,0], class1_data[:,1], 'o')
plt.plot(class2_data[:,0], class2_data[:,1], 'ro')
plt.xlabel('x1')
plt.ylabel('y1')
plt.grid()

# %% [markdown]
# ## STEP2. Make Model

# %%
from torch import nn

class MLP(nn.Module):
    def __init__(self):
        super().__init__()

        
        # case 1. plain
        self.linear = nn.Sequential(nn.Linear(2, 100),
                                    nn.Sigmoid(),
                                    nn.Linear(100, 1),
                                    nn.Sigmoid())

        # case 3. very deep
        # self.linear = nn.Sequential(nn.Linear(2, 100),
        #                        nn.ReLU(),
        #                        nn.Sequential(*[i for _ in range(10) for i in [nn.Linear(100,100), nn.ReLu()]]),
        #                        nn.Linear(100, 1),
        #                        nn.Sigmoid())

    def forward(self, x):
        x = self.linear(x)
        return x

# %%
nn.Sequential(*[i for _ in range(5) for i in [nn.Linear(100, 100), nn.Sigmoid()]])
# Out:
# Sequential(
#   (0): Linear(in_features=100, out_features=100, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): Sigmoid()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): Sigmoid()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): Sigmoid()
#   (8): Linear(in_features=100, out_features=100, bias=True)
#   (9): Sigmoid()
# )

# %%
model = MLP()
print(model)
# Out:
# MLP(
#   (linear): Sequential(
#     (0): Linear(in_features=2, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %% [markdown]
# ## STEP 3. Training Model

# %%
from torch import optim
import torch.nn.functional as F

LR = 1e-2 
EPOCH = 400 

# optimizer  = optim.SGD(model.parameters(), lr=LR) # optimizor for case 1
optimizer  = optim.Adam(model.parameters(), lr=LR)   # optimizor for case 2

loss_history = []

model.train() # change into train mode
for it in range(EPOCH):
    # inference
    y_hat = model(x)
    # loss
    loss = F.binary_cross_entropy(y_hat, y) # y_hat(prediction) should be in front of y(target) ==> (y_hat, y)
    # update
    optimizer.zero_grad() # Prevent stack of gradient
    loss.backward()       # BPP(Back Propagation)
    optimizer.step()      # Weight update
    # print loss
    loss_history += [loss.item()]
    print(f'Epoch: {it+1}, train loss: {round(loss.item(),3)}')
    print('-'*20)
# Out:
# Epoch: 1, train loss: 0.728
# --------------------
# Epoch: 2, train loss: 0.687
# --------------------
# Epoch: 3, train loss: 0.701
# --------------------
# Epoch: 4, train loss: 0.706
# --------------------
# Epoch: 5, train loss: 0.694
# --------------------
# Epoch: 6, train loss: 0.683
# --------------------
# Epoch: 7, train loss: 0.68
# --------------------
# Epoch: 8, train loss: 0.685
# --------------------
# Epoch: 9, train loss: 0.686
# --------------------
# Epoch: 10, train loss: 0.683
# --------------------
# Epoch: 11, train loss: 0.676
# --------------------
# Epoch: 12, train loss: 0.672
# --------------------
# Epoch: 13, train loss: 0.671
# --------------------
# Epoch: 14, train loss: 0.672
# --------------------
# Epoch: 15, train loss: 0.672
# --------------------
# Epoch: 16, train loss: 0.67
# --------------------
# Epoch: 17, train loss: 0.666
# --------------------
# Epoch: 18, train loss: 0.663
# --------------------
# Epoch: 19, train loss: 0.662
# --------------------
# Epoch: 20, train loss: 0.663
# --------------------
# Epoch: 21, train loss: 0.662
# --------------------
# Epoch: 22, train loss: 0.661
# --------------------
# Epoch: 23, train loss: 0.659
# --------------------
# Epoch: 24, train loss: 0.657
# --------------------
# Epoch: 25, train loss: 0.656
# --------------------
# Epoch: 26, train loss: 0.656
# --------------------
# Epoch: 27, train loss: 0.655
# --------------------
# Epoch: 28, train loss: 0.654
# --------------------
# Epoch: 29, train loss: 0.653
# --------------------
# Epoch: 30, train loss: 0.651
# --------------------
# Epoch: 31, train loss: 0.651
# --------------------
# Epoch: 32, train loss: 0.651
# --------------------
# Epoch: 33, train loss: 0.65
# --------------------
# Epoch: 34, train loss: 0.65
# --------------------
# Epoch: 35, train loss: 0.649
# --------------------
# Epoch: 36, train loss: 0.648
# --------------------
# Epoch: 37, train loss: 0.647
# --------------------
# Epoch: 38, train loss: 0.647
# --------------------
# Epoch: 39, train loss: 0.647
# --------------------
# Epoch: 40, train loss: 0.646
# --------------------
# Epoch: 41, train loss: 0.645
# --------------------
# Epoch: 42, train loss: 0.645
# --------------------
# Epoch: 43, train loss: 0.644
# --------------------
# Epoch: 44, train loss: 0.644
# --------------------
# Epoch: 45, train loss: 0.643
# --------------------
# Epoch: 46, train loss: 0.642
# --------------------
# Epoch: 47, train loss: 0.642
# --------------------
# Epoch: 48, train loss: 0.641
# --------------------
# Epoch: 49, train loss: 0.64
# --------------------
# Epoch: 50, train loss: 0.64
# --------------------
# Epoch: 51, train loss: 0.639
# --------------------
# Epoch: 52, train loss: 0.638
# --------------------
# Epoch: 53, train loss: 0.637
# --------------------
# Epoch: 54, train loss: 0.636
# --------------------
# Epoch: 55, train loss: 0.636
# --------------------
# Epoch: 56, train loss: 0.635
# --------------------
# Epoch: 57, train loss: 0.634
# --------------------
# Epoch: 58, train loss: 0.633
# --------------------
# Epoch: 59, train loss: 0.632
# --------------------
# Epoch: 60, train loss: 0.631
# --------------------
# Epoch: 61, train loss: 0.63
# --------------------
# Epoch: 62, train loss: 0.628
# --------------------
# Epoch: 63, train loss: 0.627
# --------------------
# Epoch: 64, train loss: 0.626
# --------------------
# Epoch: 65, train loss: 0.625
# --------------------
# Epoch: 66, train loss: 0.623
# --------------------
# Epoch: 67, train loss: 0.622
# --------------------
# Epoch: 68, train loss: 0.62
# --------------------
# Epoch: 69, train loss: 0.619
# --------------------
# Epoch: 70, train loss: 0.617
# --------------------
# Epoch: 71, train loss: 0.616
# --------------------
# Epoch: 72, train loss: 0.614
# --------------------
# Epoch: 73, train loss: 0.612
# --------------------
# Epoch: 74, train loss: 0.611
# --------------------
# Epoch: 75, train loss: 0.609
# --------------------
# Epoch: 76, train loss: 0.607
# --------------------
# Epoch: 77, train loss: 0.605
# --------------------
# Epoch: 78, train loss: 0.603
# --------------------
# Epoch: 79, train loss: 0.6
# --------------------
# Epoch: 80, train loss: 0.598
# --------------------
# Epoch: 81, train loss: 0.596
# --------------------
# Epoch: 82, train loss: 0.593
# --------------------
# Epoch: 83, train loss: 0.591
# --------------------
# Epoch: 84, train loss: 0.588
# --------------------
# Epoch: 85, train loss: 0.585
# --------------------
# Epoch: 86, train loss: 0.582
# --------------------
# Epoch: 87, train loss: 0.58
# --------------------
# Epoch: 88, train loss: 0.576
# --------------------
# Epoch: 89, train loss: 0.573
# --------------------
# Epoch: 90, train loss: 0.57
# --------------------
# Epoch: 91, train loss: 0.567
# --------------------
# Epoch: 92, train loss: 0.563
# --------------------
# Epoch: 93, train loss: 0.56
# --------------------
# Epoch: 94, train loss: 0.556
# --------------------
# Epoch: 95, train loss: 0.552
# --------------------
# Epoch: 96, train loss: 0.548
# --------------------
# Epoch: 97, train loss: 0.544
# --------------------
# Epoch: 98, train loss: 0.54
# --------------------
# Epoch: 99, train loss: 0.536
# --------------------
# Epoch: 100, train loss: 0.531
# --------------------
# Epoch: 101, train loss: 0.527
# --------------------
# Epoch: 102, train loss: 0.522
# --------------------
# Epoch: 103, train loss: 0.517
# --------------------
# Epoch: 104, train loss: 0.512
# --------------------
# Epoch: 105, train loss: 0.507
# --------------------
# Epoch: 106, train loss: 0.502
# --------------------
# Epoch: 107, train loss: 0.497
# --------------------
# Epoch: 108, train loss: 0.491
# --------------------
# Epoch: 109, train loss: 0.486
# --------------------
# Epoch: 110, train loss: 0.48
# --------------------
# Epoch: 111, train loss: 0.475
# --------------------
# Epoch: 112, train loss: 0.469
# --------------------
# Epoch: 113, train loss: 0.463
# --------------------
# Epoch: 114, train loss: 0.457
# --------------------
# Epoch: 115, train loss: 0.451
# --------------------
# Epoch: 116, train loss: 0.444
# --------------------
# Epoch: 117, train loss: 0.438
# --------------------
# Epoch: 118, train loss: 0.432
# --------------------
# Epoch: 119, train loss: 0.425
# --------------------
# Epoch: 120, train loss: 0.419
# --------------------
# Epoch: 121, train loss: 0.412
# --------------------
# Epoch: 122, train loss: 0.405
# --------------------
# Epoch: 123, train loss: 0.399
# --------------------
# Epoch: 124, train loss: 0.392
# --------------------
# Epoch: 125, train loss: 0.385
# --------------------
# Epoch: 126, train loss: 0.378
# --------------------
# Epoch: 127, train loss: 0.371
# --------------------
# Epoch: 128, train loss: 0.365
# --------------------
# Epoch: 129, train loss: 0.358
# --------------------
# Epoch: 130, train loss: 0.351
# --------------------
# Epoch: 131, train loss: 0.344
# --------------------
# Epoch: 132, train loss: 0.337
# --------------------
# Epoch: 133, train loss: 0.33
# --------------------
# Epoch: 134, train loss: 0.323
# --------------------
# Epoch: 135, train loss: 0.316
# --------------------
# Epoch: 136, train loss: 0.31
# --------------------
# Epoch: 137, train loss: 0.303
# --------------------
# Epoch: 138, train loss: 0.296
# --------------------
# Epoch: 139, train loss: 0.289
# --------------------
# Epoch: 140, train loss: 0.283
# --------------------
# Epoch: 141, train loss: 0.276
# --------------------
# Epoch: 142, train loss: 0.27
# --------------------
# Epoch: 143, train loss: 0.263
# --------------------
# Epoch: 144, train loss: 0.257
# --------------------
# Epoch: 145, train loss: 0.25
# --------------------
# Epoch: 146, train loss: 0.244
# --------------------
# Epoch: 147, train loss: 0.238
# --------------------
# Epoch: 148, train loss: 0.232
# --------------------
# Epoch: 149, train loss: 0.226
# --------------------
# Epoch: 150, train loss: 0.22
# --------------------
# Epoch: 151, train loss: 0.214
# --------------------
# Epoch: 152, train loss: 0.208
# --------------------
# Epoch: 153, train loss: 0.202
# --------------------
# Epoch: 154, train loss: 0.197
# --------------------
# Epoch: 155, train loss: 0.191
# --------------------
# Epoch: 156, train loss: 0.186
# --------------------
# Epoch: 157, train loss: 0.181
# --------------------
# Epoch: 158, train loss: 0.176
# --------------------
# Epoch: 159, train loss: 0.171
# --------------------
# Epoch: 160, train loss: 0.166
# --------------------
# Epoch: 161, train loss: 0.161
# --------------------
# Epoch: 162, train loss: 0.156
# --------------------
# Epoch: 163, train loss: 0.152
# --------------------
# Epoch: 164, train loss: 0.147
# --------------------
# Epoch: 165, train loss: 0.143
# --------------------
# Epoch: 166, train loss: 0.139
# --------------------
# Epoch: 167, train loss: 0.135
# --------------------
# Epoch: 168, train loss: 0.131
# --------------------
# Epoch: 169, train loss: 0.127
# --------------------
# Epoch: 170, train loss: 0.123
# --------------------
# Epoch: 171, train loss: 0.119
# --------------------
# Epoch: 172, train loss: 0.116
# --------------------
# Epoch: 173, train loss: 0.112
# --------------------
# Epoch: 174, train loss: 0.109
# --------------------
# Epoch: 175, train loss: 0.106
# --------------------
# Epoch: 176, train loss: 0.103
# --------------------
# Epoch: 177, train loss: 0.1
# --------------------
# Epoch: 178, train loss: 0.097
# --------------------
# Epoch: 179, train loss: 0.094
# --------------------
# Epoch: 180, train loss: 0.091
# --------------------
# Epoch: 181, train loss: 0.089
# --------------------
# Epoch: 182, train loss: 0.086
# --------------------
# Epoch: 183, train loss: 0.084
# --------------------
# Epoch: 184, train loss: 0.082
# --------------------
# Epoch: 185, train loss: 0.079
# --------------------
# Epoch: 186, train loss: 0.077
# --------------------
# Epoch: 187, train loss: 0.075
# --------------------
# Epoch: 188, train loss: 0.073
# --------------------
# Epoch: 189, train loss: 0.071
# --------------------
# Epoch: 190, train loss: 0.069
# --------------------
# Epoch: 191, train loss: 0.068
# --------------------
# Epoch: 192, train loss: 0.066
# --------------------
# Epoch: 193, train loss: 0.064
# --------------------
# Epoch: 194, train loss: 0.063
# --------------------
# Epoch: 195, train loss: 0.061
# --------------------
# Epoch: 196, train loss: 0.06
# --------------------
# Epoch: 197, train loss: 0.058
# --------------------
# Epoch: 198, train loss: 0.057
# --------------------
# Epoch: 199, train loss: 0.056
# --------------------
# Epoch: 200, train loss: 0.054
# --------------------
# Epoch: 201, train loss: 0.053
# --------------------
# Epoch: 202, train loss: 0.052
# --------------------
# Epoch: 203, train loss: 0.051
# --------------------
# Epoch: 204, train loss: 0.05
# --------------------
# Epoch: 205, train loss: 0.049
# --------------------
# Epoch: 206, train loss: 0.047
# --------------------
# Epoch: 207, train loss: 0.046
# --------------------
# Epoch: 208, train loss: 0.046
# --------------------
# Epoch: 209, train loss: 0.045
# --------------------
# Epoch: 210, train loss: 0.044
# --------------------
# Epoch: 211, train loss: 0.043
# --------------------
# Epoch: 212, train loss: 0.042
# --------------------
# Epoch: 213, train loss: 0.041
# --------------------
# Epoch: 214, train loss: 0.04
# --------------------
# Epoch: 215, train loss: 0.04
# --------------------
# Epoch: 216, train loss: 0.039
# --------------------
# Epoch: 217, train loss: 0.038
# --------------------
# Epoch: 218, train loss: 0.038
# --------------------
# Epoch: 219, train loss: 0.037
# --------------------
# Epoch: 220, train loss: 0.036
# --------------------
# Epoch: 221, train loss: 0.036
# --------------------
# Epoch: 222, train loss: 0.035
# --------------------
# Epoch: 223, train loss: 0.034
# --------------------
# Epoch: 224, train loss: 0.034
# --------------------
# Epoch: 225, train loss: 0.033
# --------------------
# Epoch: 226, train loss: 0.033
# --------------------
# Epoch: 227, train loss: 0.032
# --------------------
# Epoch: 228, train loss: 0.032
# --------------------
# Epoch: 229, train loss: 0.031
# --------------------
# Epoch: 230, train loss: 0.031
# --------------------
# Epoch: 231, train loss: 0.03
# --------------------
# Epoch: 232, train loss: 0.03
# --------------------
# Epoch: 233, train loss: 0.029
# --------------------
# Epoch: 234, train loss: 0.029
# --------------------
# Epoch: 235, train loss: 0.028
# --------------------
# Epoch: 236, train loss: 0.028
# --------------------
# Epoch: 237, train loss: 0.028
# --------------------
# Epoch: 238, train loss: 0.027
# --------------------
# Epoch: 239, train loss: 0.027
# --------------------
# Epoch: 240, train loss: 0.026
# --------------------
# Epoch: 241, train loss: 0.026
# --------------------
# Epoch: 242, train loss: 0.026
# --------------------
# Epoch: 243, train loss: 0.025
# --------------------
# Epoch: 244, train loss: 0.025
# --------------------
# Epoch: 245, train loss: 0.025
# --------------------
# Epoch: 246, train loss: 0.024
# --------------------
# Epoch: 247, train loss: 0.024
# --------------------
# Epoch: 248, train loss: 0.024
# --------------------
# Epoch: 249, train loss: 0.023
# --------------------
# Epoch: 250, train loss: 0.023
# --------------------
# Epoch: 251, train loss: 0.023
# --------------------
# Epoch: 252, train loss: 0.023
# --------------------
# Epoch: 253, train loss: 0.022
# --------------------
# Epoch: 254, train loss: 0.022
# --------------------
# Epoch: 255, train loss: 0.022
# --------------------
# Epoch: 256, train loss: 0.022
# --------------------
# Epoch: 257, train loss: 0.021
# --------------------
# Epoch: 258, train loss: 0.021
# --------------------
# Epoch: 259, train loss: 0.021
# --------------------
# Epoch: 260, train loss: 0.021
# --------------------
# Epoch: 261, train loss: 0.02
# --------------------
# Epoch: 262, train loss: 0.02
# --------------------
# Epoch: 263, train loss: 0.02
# --------------------
# Epoch: 264, train loss: 0.02
# --------------------
# Epoch: 265, train loss: 0.019
# --------------------
# Epoch: 266, train loss: 0.019
# --------------------
# Epoch: 267, train loss: 0.019
# --------------------
# Epoch: 268, train loss: 0.019
# --------------------
# Epoch: 269, train loss: 0.019
# --------------------
# Epoch: 270, train loss: 0.018
# --------------------
# Epoch: 271, train loss: 0.018
# --------------------
# Epoch: 272, train loss: 0.018
# --------------------
# Epoch: 273, train loss: 0.018
# --------------------
# Epoch: 274, train loss: 0.018
# --------------------
# Epoch: 275, train loss: 0.017
# --------------------
# Epoch: 276, train loss: 0.017
# --------------------
# Epoch: 277, train loss: 0.017
# --------------------
# Epoch: 278, train loss: 0.017
# --------------------
# Epoch: 279, train loss: 0.017
# --------------------
# Epoch: 280, train loss: 0.017
# --------------------
# Epoch: 281, train loss: 0.016
# --------------------
# Epoch: 282, train loss: 0.016
# --------------------
# Epoch: 283, train loss: 0.016
# --------------------
# Epoch: 284, train loss: 0.016
# --------------------
# Epoch: 285, train loss: 0.016
# --------------------
# Epoch: 286, train loss: 0.016
# --------------------
# Epoch: 287, train loss: 0.015
# --------------------
# Epoch: 288, train loss: 0.015
# --------------------
# Epoch: 289, train loss: 0.015
# --------------------
# Epoch: 290, train loss: 0.015
# --------------------
# Epoch: 291, train loss: 0.015
# --------------------
# Epoch: 292, train loss: 0.015
# --------------------
# Epoch: 293, train loss: 0.015
# --------------------
# Epoch: 294, train loss: 0.014
# --------------------
# Epoch: 295, train loss: 0.014
# --------------------
# Epoch: 296, train loss: 0.014
# --------------------
# Epoch: 297, train loss: 0.014
# --------------------
# Epoch: 298, train loss: 0.014
# --------------------
# Epoch: 299, train loss: 0.014
# --------------------
# Epoch: 300, train loss: 0.014
# --------------------
# Epoch: 301, train loss: 0.014
# --------------------
# Epoch: 302, train loss: 0.013
# --------------------
# Epoch: 303, train loss: 0.013
# --------------------
# Epoch: 304, train loss: 0.013
# --------------------
# Epoch: 305, train loss: 0.013
# --------------------
# Epoch: 306, train loss: 0.013
# --------------------
# Epoch: 307, train loss: 0.013
# --------------------
# Epoch: 308, train loss: 0.013
# --------------------
# Epoch: 309, train loss: 0.013
# --------------------
# Epoch: 310, train loss: 0.012
# --------------------
# Epoch: 311, train loss: 0.012
# --------------------
# Epoch: 312, train loss: 0.012
# --------------------
# Epoch: 313, train loss: 0.012
# --------------------
# Epoch: 314, train loss: 0.012
# --------------------
# Epoch: 315, train loss: 0.012
# --------------------
# Epoch: 316, train loss: 0.012
# --------------------
# Epoch: 317, train loss: 0.012
# --------------------
# Epoch: 318, train loss: 0.012
# --------------------
# Epoch: 319, train loss: 0.012
# --------------------
# Epoch: 320, train loss: 0.011
# --------------------
# Epoch: 321, train loss: 0.011
# --------------------
# Epoch: 322, train loss: 0.011
# --------------------
# Epoch: 323, train loss: 0.011
# --------------------
# Epoch: 324, train loss: 0.011
# --------------------
# Epoch: 325, train loss: 0.011
# --------------------
# Epoch: 326, train loss: 0.011
# --------------------
# Epoch: 327, train loss: 0.011
# --------------------
# Epoch: 328, train loss: 0.011
# --------------------
# Epoch: 329, train loss: 0.011
# --------------------
# Epoch: 330, train loss: 0.011
# --------------------
# Epoch: 331, train loss: 0.011
# --------------------
# Epoch: 332, train loss: 0.01
# --------------------
# Epoch: 333, train loss: 0.01
# --------------------
# Epoch: 334, train loss: 0.01
# --------------------
# Epoch: 335, train loss: 0.01
# --------------------
# Epoch: 336, train loss: 0.01
# --------------------
# Epoch: 337, train loss: 0.01
# --------------------
# Epoch: 338, train loss: 0.01
# --------------------
# Epoch: 339, train loss: 0.01
# --------------------
# Epoch: 340, train loss: 0.01
# --------------------
# Epoch: 341, train loss: 0.01
# --------------------
# Epoch: 342, train loss: 0.01
# --------------------
# Epoch: 343, train loss: 0.01
# --------------------
# Epoch: 344, train loss: 0.01
# --------------------
# Epoch: 345, train loss: 0.009
# --------------------
# Epoch: 346, train loss: 0.009
# --------------------
# Epoch: 347, train loss: 0.009
# --------------------
# Epoch: 348, train loss: 0.009
# --------------------
# Epoch: 349, train loss: 0.009
# --------------------
# Epoch: 350, train loss: 0.009
# --------------------
# Epoch: 351, train loss: 0.009
# --------------------
# Epoch: 352, train loss: 0.009
# --------------------
# Epoch: 353, train loss: 0.009
# --------------------
# Epoch: 354, train loss: 0.009
# --------------------
# Epoch: 355, train loss: 0.009
# --------------------
# Epoch: 356, train loss: 0.009
# --------------------
# Epoch: 357, train loss: 0.009
# --------------------
# Epoch: 358, train loss: 0.009
# --------------------
# Epoch: 359, train loss: 0.009
# --------------------
# Epoch: 360, train loss: 0.009
# --------------------
# Epoch: 361, train loss: 0.008
# --------------------
# Epoch: 362, train loss: 0.008
# --------------------
# Epoch: 363, train loss: 0.008
# --------------------
# Epoch: 364, train loss: 0.008
# --------------------
# Epoch: 365, train loss: 0.008
# --------------------
# Epoch: 366, train loss: 0.008
# --------------------
# Epoch: 367, train loss: 0.008
# --------------------
# Epoch: 368, train loss: 0.008
# --------------------
# Epoch: 369, train loss: 0.008
# --------------------
# Epoch: 370, train loss: 0.008
# --------------------
# Epoch: 371, train loss: 0.008
# --------------------
# Epoch: 372, train loss: 0.008
# --------------------
# Epoch: 373, train loss: 0.008
# --------------------
# Epoch: 374, train loss: 0.008
# --------------------
# Epoch: 375, train loss: 0.008
# --------------------
# Epoch: 376, train loss: 0.008
# --------------------
# Epoch: 377, train loss: 0.008
# --------------------
# Epoch: 378, train loss: 0.008
# --------------------
# Epoch: 379, train loss: 0.008
# --------------------
# Epoch: 380, train loss: 0.007
# --------------------
# Epoch: 381, train loss: 0.007
# --------------------
# Epoch: 382, train loss: 0.007
# --------------------
# Epoch: 383, train loss: 0.007
# --------------------
# Epoch: 384, train loss: 0.007
# --------------------
# Epoch: 385, train loss: 0.007
# --------------------
# Epoch: 386, train loss: 0.007
# --------------------
# Epoch: 387, train loss: 0.007
# --------------------
# Epoch: 388, train loss: 0.007
# --------------------
# Epoch: 389, train loss: 0.007
# --------------------
# Epoch: 390, train loss: 0.007
# --------------------
# Epoch: 391, train loss: 0.007
# --------------------
# Epoch: 392, train loss: 0.007
# --------------------
# Epoch: 393, train loss: 0.007
# --------------------
# Epoch: 394, train loss: 0.007
# --------------------
# Epoch: 395, train loss: 0.007
# --------------------
# Epoch: 396, train loss: 0.007
# --------------------
# Epoch: 397, train loss: 0.007
# --------------------
# Epoch: 398, train loss: 0.007
# --------------------
# Epoch: 399, train loss: 0.007
# --------------------
# Epoch: 400, train loss: 0.007
# --------------------

# %%
x = torch.tensor([1.], requires_grad=True)
for _ in range(2):
    loss=x**2
    loss.backward()
    print(x.grad)    # if you use loss.backward() without The functions below, the result would be stacked by addition.  
    x.grad = None    # x.grad = 0 doesn't work
# Out:
# tensor([2.])
# tensor([2.])

# %%
print(F.binary_cross_entropy(y_hat, y))
print(-torch.sum(torch.log(y_hat**y*(1-y_hat)**(1-y)))/N)
# Out:
# tensor(0.0066, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0066, grad_fn=<DivBackward0>)

# %%
plt.plot(loss_history)
plt.xlabel('Epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## STEP 4. Model Test

# %%
x1_test = torch.linspace(-10,10,30) # case 1
x2_test = torch.linspace(-10,10,30) # case 2
X1_test, X2_test = torch.meshgrid(x1_test, x2_test)
X_test = torch.cat([X1_test.unsqueeze(dim=2), X2_test.unsqueeze(dim=2)], dim=2)


model.eval()      # change into test mode 
with torch.no_grad():
    y_hat = model(X_test)
# 1. Train mode and Test mode in Dropout or BN have quite different operation! so you should use eval() function!
# 2. Calculate grad_fn <- it is unnecessary!

Y_hat = y_hat.squeeze()

plt.figure(figsize=[10, 9])  # figsize=[가로, 세로]
ax = plt.axes(projection='3d')
ax.view_init(elev=25,azim=-140)
ax.plot_surface(X1_test, X2_test, Y_hat.numpy(), cmap='viridis', alpha=0.2)
plt.plot(class1_data[:,0],class1_data[:,1],class1_label.squeeze(),'bo')
plt.plot(class2_data[:,0],class2_data[:,1],class2_label.squeeze(),'ro')
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# Text(0.5, 0.5, 'x2')
