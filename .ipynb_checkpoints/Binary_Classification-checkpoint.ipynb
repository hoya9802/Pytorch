# %%
import torch

# %% [markdown]
# ## STEP 1. Make data

# %%
# choose the dataset you want
# case 1
# N = 20
# random0 = torch.randn(int(N/2), 1)
# random5 = torch.randn(int(N/2), 1) + 5
# class1_data = torch.hstack([random0, random5])
# class2_data = torch.hstack([random5, random0])

# class1_label = torch.ones(int(N/2),1)
# class2_label = torch.zeros(int(N/2),1)
# x = torch.vstack([class1_data, class2_data])
# y = torch.vstack([class1_label, class2_label])

# case 2
N = 100
radius1=0.3+0.05*torch.randn(int(N/2),1)
radius2=1+0.01*torch.randn(int(N/2),1)
theta1=2*torch.pi*torch.rand(int(N/2),1)-torch.pi
theta2=2*torch.pi*torch.rand(int(N/2),1)-torch.pi
class1_data=torch.hstack([radius1*torch.cos(theta1), radius1*torch.sin(theta1)])
class2_data=torch.hstack([radius2*torch.cos(theta2), radius2*torch.sin(theta2)])
class1_label=torch.ones(int(N/2),1)
class2_label=torch.zeros(int(N/2),1)
x = torch.vstack([class1_data, class2_data])
y = torch.vstack([class1_label, class2_label])

# %%
import matplotlib.pyplot as plt
plt.plot(class1_data[:,0], class1_data[:,1], 'o')
plt.plot(class2_data[:,0], class2_data[:,1], 'ro')
plt.xlabel('x1')
plt.ylabel('y1')
plt.grid()

# %% [markdown]
# ## STEP2. Make Model

# %%
from torch import nn

class MLP(nn.Module):
    def __init__(self):
        super().__init__()

        
        # case 1, plain
        self.linear = nn.Sequential(nn.Linear(2, 100),
                                    nn.Sigmoid(),
                                    nn.Linear(100, 1),
                                    nn.Sigmoid())

    def forward(self, x):
        x = self.linear(x)
        return x

# %%
model = MLP()
print(model)
# Out:
# MLP(
#   (linear): Sequential(
#     (0): Linear(in_features=2, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %% [markdown]
# ## STEP 3. Training Model

# %%
from torch import optim
import torch.nn.functional as F

LR = 1e-2 
EPOCH = 400 

# optimizer  = optim.SGD(model.parameters(), lr=LR) # optimizor for case 1
optimizer  = optim.adam(model.parameters(), lr=LR)   # optimizor for case 2

loss_history = []

model.train() # change into train mode
for it in range(EPOCH):
    # inference
    y_hat = model(x)
    # loss
    loss = F.binary_cross_entropy(y_hat, y) # y_hat(prediction) should be in front of y(target) ==> (y_hat, y)
    # update
    optimizer.zero_grad() # Prevent stack of gradient
    loss.backward()       # BPP(Back Propagation)
    optimizer.step()      # Weight update
    # print loss
    loss_history += [loss.item()]
    print(f'Epoch: {it+1}, train loss: {round(loss.item(),3)}')
    print('-'*20)
# Out:
# Epoch: 1, train loss: 0.71
# --------------------
# Epoch: 2, train loss: 0.694
# --------------------
# Epoch: 3, train loss: 0.703
# --------------------
# Epoch: 4, train loss: 0.695
# --------------------
# Epoch: 5, train loss: 0.688
# --------------------
# Epoch: 6, train loss: 0.689
# --------------------
# Epoch: 7, train loss: 0.691
# --------------------
# Epoch: 8, train loss: 0.689
# --------------------
# Epoch: 9, train loss: 0.684
# --------------------
# Epoch: 10, train loss: 0.682
# --------------------
# Epoch: 11, train loss: 0.683
# --------------------
# Epoch: 12, train loss: 0.684
# --------------------
# Epoch: 13, train loss: 0.682
# --------------------
# Epoch: 14, train loss: 0.68
# --------------------
# Epoch: 15, train loss: 0.678
# --------------------
# Epoch: 16, train loss: 0.678
# --------------------
# Epoch: 17, train loss: 0.679
# --------------------
# Epoch: 18, train loss: 0.678
# --------------------
# Epoch: 19, train loss: 0.677
# --------------------
# Epoch: 20, train loss: 0.676
# --------------------
# Epoch: 21, train loss: 0.675
# --------------------
# Epoch: 22, train loss: 0.676
# --------------------
# Epoch: 23, train loss: 0.676
# --------------------
# Epoch: 24, train loss: 0.675
# --------------------
# Epoch: 25, train loss: 0.674
# --------------------
# Epoch: 26, train loss: 0.674
# --------------------
# Epoch: 27, train loss: 0.674
# --------------------
# Epoch: 28, train loss: 0.674
# --------------------
# Epoch: 29, train loss: 0.673
# --------------------
# Epoch: 30, train loss: 0.672
# --------------------
# Epoch: 31, train loss: 0.672
# --------------------
# Epoch: 32, train loss: 0.672
# --------------------
# Epoch: 33, train loss: 0.672
# --------------------
# Epoch: 34, train loss: 0.671
# --------------------
# Epoch: 35, train loss: 0.67
# --------------------
# Epoch: 36, train loss: 0.67
# --------------------
# Epoch: 37, train loss: 0.67
# --------------------
# Epoch: 38, train loss: 0.669
# --------------------
# Epoch: 39, train loss: 0.669
# --------------------
# Epoch: 40, train loss: 0.668
# --------------------
# Epoch: 41, train loss: 0.668
# --------------------
# Epoch: 42, train loss: 0.667
# --------------------
# Epoch: 43, train loss: 0.667
# --------------------
# Epoch: 44, train loss: 0.666
# --------------------
# Epoch: 45, train loss: 0.666
# --------------------
# Epoch: 46, train loss: 0.665
# --------------------
# Epoch: 47, train loss: 0.665
# --------------------
# Epoch: 48, train loss: 0.664
# --------------------
# Epoch: 49, train loss: 0.663
# --------------------
# Epoch: 50, train loss: 0.663
# --------------------
# Epoch: 51, train loss: 0.662
# --------------------
# Epoch: 52, train loss: 0.661
# --------------------
# Epoch: 53, train loss: 0.661
# --------------------
# Epoch: 54, train loss: 0.66
# --------------------
# Epoch: 55, train loss: 0.659
# --------------------
# Epoch: 56, train loss: 0.658
# --------------------
# Epoch: 57, train loss: 0.658
# --------------------
# Epoch: 58, train loss: 0.657
# --------------------
# Epoch: 59, train loss: 0.656
# --------------------
# Epoch: 60, train loss: 0.655
# --------------------
# Epoch: 61, train loss: 0.654
# --------------------
# Epoch: 62, train loss: 0.653
# --------------------
# Epoch: 63, train loss: 0.652
# --------------------
# Epoch: 64, train loss: 0.651
# --------------------
# Epoch: 65, train loss: 0.649
# --------------------
# Epoch: 66, train loss: 0.648
# --------------------
# Epoch: 67, train loss: 0.647
# --------------------
# Epoch: 68, train loss: 0.645
# --------------------
# Epoch: 69, train loss: 0.644
# --------------------
# Epoch: 70, train loss: 0.643
# --------------------
# Epoch: 71, train loss: 0.641
# --------------------
# Epoch: 72, train loss: 0.639
# --------------------
# Epoch: 73, train loss: 0.638
# --------------------
# Epoch: 74, train loss: 0.636
# --------------------
# Epoch: 75, train loss: 0.634
# --------------------
# Epoch: 76, train loss: 0.632
# --------------------
# Epoch: 77, train loss: 0.63
# --------------------
# Epoch: 78, train loss: 0.628
# --------------------
# Epoch: 79, train loss: 0.626
# --------------------
# Epoch: 80, train loss: 0.623
# --------------------
# Epoch: 81, train loss: 0.621
# --------------------
# Epoch: 82, train loss: 0.618
# --------------------
# Epoch: 83, train loss: 0.616
# --------------------
# Epoch: 84, train loss: 0.613
# --------------------
# Epoch: 85, train loss: 0.61
# --------------------
# Epoch: 86, train loss: 0.607
# --------------------
# Epoch: 87, train loss: 0.603
# --------------------
# Epoch: 88, train loss: 0.6
# --------------------
# Epoch: 89, train loss: 0.596
# --------------------
# Epoch: 90, train loss: 0.593
# --------------------
# Epoch: 91, train loss: 0.589
# --------------------
# Epoch: 92, train loss: 0.585
# --------------------
# Epoch: 93, train loss: 0.58
# --------------------
# Epoch: 94, train loss: 0.576
# --------------------
# Epoch: 95, train loss: 0.571
# --------------------
# Epoch: 96, train loss: 0.566
# --------------------
# Epoch: 97, train loss: 0.561
# --------------------
# Epoch: 98, train loss: 0.556
# --------------------
# Epoch: 99, train loss: 0.551
# --------------------
# Epoch: 100, train loss: 0.545
# --------------------
# Epoch: 101, train loss: 0.539
# --------------------
# Epoch: 102, train loss: 0.533
# --------------------
# Epoch: 103, train loss: 0.526
# --------------------
# Epoch: 104, train loss: 0.52
# --------------------
# Epoch: 105, train loss: 0.513
# --------------------
# Epoch: 106, train loss: 0.506
# --------------------
# Epoch: 107, train loss: 0.499
# --------------------
# Epoch: 108, train loss: 0.491
# --------------------
# Epoch: 109, train loss: 0.484
# --------------------
# Epoch: 110, train loss: 0.476
# --------------------
# Epoch: 111, train loss: 0.468
# --------------------
# Epoch: 112, train loss: 0.46
# --------------------
# Epoch: 113, train loss: 0.451
# --------------------
# Epoch: 114, train loss: 0.443
# --------------------
# Epoch: 115, train loss: 0.434
# --------------------
# Epoch: 116, train loss: 0.425
# --------------------
# Epoch: 117, train loss: 0.416
# --------------------
# Epoch: 118, train loss: 0.407
# --------------------
# Epoch: 119, train loss: 0.398
# --------------------
# Epoch: 120, train loss: 0.388
# --------------------
# Epoch: 121, train loss: 0.379
# --------------------
# Epoch: 122, train loss: 0.37
# --------------------
# Epoch: 123, train loss: 0.36
# --------------------
# Epoch: 124, train loss: 0.351
# --------------------
# Epoch: 125, train loss: 0.342
# --------------------
# Epoch: 126, train loss: 0.332
# --------------------
# Epoch: 127, train loss: 0.323
# --------------------
# Epoch: 128, train loss: 0.314
# --------------------
# Epoch: 129, train loss: 0.305
# --------------------
# Epoch: 130, train loss: 0.296
# --------------------
# Epoch: 131, train loss: 0.287
# --------------------
# Epoch: 132, train loss: 0.278
# --------------------
# Epoch: 133, train loss: 0.269
# --------------------
# Epoch: 134, train loss: 0.261
# --------------------
# Epoch: 135, train loss: 0.253
# --------------------
# Epoch: 136, train loss: 0.245
# --------------------
# Epoch: 137, train loss: 0.237
# --------------------
# Epoch: 138, train loss: 0.229
# --------------------
# Epoch: 139, train loss: 0.221
# --------------------
# Epoch: 140, train loss: 0.214
# --------------------
# Epoch: 141, train loss: 0.207
# --------------------
# Epoch: 142, train loss: 0.2
# --------------------
# Epoch: 143, train loss: 0.193
# --------------------
# Epoch: 144, train loss: 0.187
# --------------------
# Epoch: 145, train loss: 0.18
# --------------------
# Epoch: 146, train loss: 0.174
# --------------------
# Epoch: 147, train loss: 0.168
# --------------------
# Epoch: 148, train loss: 0.163
# --------------------
# Epoch: 149, train loss: 0.157
# --------------------
# Epoch: 150, train loss: 0.152
# --------------------
# Epoch: 151, train loss: 0.147
# --------------------
# Epoch: 152, train loss: 0.142
# --------------------
# Epoch: 153, train loss: 0.137
# --------------------
# Epoch: 154, train loss: 0.133
# --------------------
# Epoch: 155, train loss: 0.128
# --------------------
# Epoch: 156, train loss: 0.124
# --------------------
# Epoch: 157, train loss: 0.12
# --------------------
# Epoch: 158, train loss: 0.116
# --------------------
# Epoch: 159, train loss: 0.113
# --------------------
# Epoch: 160, train loss: 0.109
# --------------------
# Epoch: 161, train loss: 0.106
# --------------------
# Epoch: 162, train loss: 0.102
# --------------------
# Epoch: 163, train loss: 0.099
# --------------------
# Epoch: 164, train loss: 0.096
# --------------------
# Epoch: 165, train loss: 0.093
# --------------------
# Epoch: 166, train loss: 0.09
# --------------------
# Epoch: 167, train loss: 0.088
# --------------------
# Epoch: 168, train loss: 0.085
# --------------------
# Epoch: 169, train loss: 0.082
# --------------------
# Epoch: 170, train loss: 0.08
# --------------------
# Epoch: 171, train loss: 0.078
# --------------------
# Epoch: 172, train loss: 0.076
# --------------------
# Epoch: 173, train loss: 0.073
# --------------------
# Epoch: 174, train loss: 0.071
# --------------------
# Epoch: 175, train loss: 0.07
# --------------------
# Epoch: 176, train loss: 0.068
# --------------------
# Epoch: 177, train loss: 0.066
# --------------------
# Epoch: 178, train loss: 0.064
# --------------------
# Epoch: 179, train loss: 0.062
# --------------------
# Epoch: 180, train loss: 0.061
# --------------------
# Epoch: 181, train loss: 0.059
# --------------------
# Epoch: 182, train loss: 0.058
# --------------------
# Epoch: 183, train loss: 0.056
# --------------------
# Epoch: 184, train loss: 0.055
# --------------------
# Epoch: 185, train loss: 0.054
# --------------------
# Epoch: 186, train loss: 0.052
# --------------------
# Epoch: 187, train loss: 0.051
# --------------------
# Epoch: 188, train loss: 0.05
# --------------------
# Epoch: 189, train loss: 0.049
# --------------------
# Epoch: 190, train loss: 0.048
# --------------------
# Epoch: 191, train loss: 0.047
# --------------------
# Epoch: 192, train loss: 0.046
# --------------------
# Epoch: 193, train loss: 0.045
# --------------------
# Epoch: 194, train loss: 0.044
# --------------------
# Epoch: 195, train loss: 0.043
# --------------------
# Epoch: 196, train loss: 0.042
# --------------------
# Epoch: 197, train loss: 0.041
# --------------------
# Epoch: 198, train loss: 0.04
# --------------------
# Epoch: 199, train loss: 0.039
# --------------------
# Epoch: 200, train loss: 0.038
# --------------------
# Epoch: 201, train loss: 0.038
# --------------------
# Epoch: 202, train loss: 0.037
# --------------------
# Epoch: 203, train loss: 0.036
# --------------------
# Epoch: 204, train loss: 0.036
# --------------------
# Epoch: 205, train loss: 0.035
# --------------------
# Epoch: 206, train loss: 0.034
# --------------------
# Epoch: 207, train loss: 0.034
# --------------------
# Epoch: 208, train loss: 0.033
# --------------------
# Epoch: 209, train loss: 0.032
# --------------------
# Epoch: 210, train loss: 0.032
# --------------------
# Epoch: 211, train loss: 0.031
# --------------------
# Epoch: 212, train loss: 0.031
# --------------------
# Epoch: 213, train loss: 0.03
# --------------------
# Epoch: 214, train loss: 0.03
# --------------------
# Epoch: 215, train loss: 0.029
# --------------------
# Epoch: 216, train loss: 0.029
# --------------------
# Epoch: 217, train loss: 0.028
# --------------------
# Epoch: 218, train loss: 0.028
# --------------------
# Epoch: 219, train loss: 0.027
# --------------------
# Epoch: 220, train loss: 0.027
# --------------------
# Epoch: 221, train loss: 0.026
# --------------------
# Epoch: 222, train loss: 0.026
# --------------------
# Epoch: 223, train loss: 0.026
# --------------------
# Epoch: 224, train loss: 0.025
# --------------------
# Epoch: 225, train loss: 0.025
# --------------------
# Epoch: 226, train loss: 0.024
# --------------------
# Epoch: 227, train loss: 0.024
# --------------------
# Epoch: 228, train loss: 0.024
# --------------------
# Epoch: 229, train loss: 0.023
# --------------------
# Epoch: 230, train loss: 0.023
# --------------------
# Epoch: 231, train loss: 0.023
# --------------------
# Epoch: 232, train loss: 0.022
# --------------------
# Epoch: 233, train loss: 0.022
# --------------------
# Epoch: 234, train loss: 0.022
# --------------------
# Epoch: 235, train loss: 0.021
# --------------------
# Epoch: 236, train loss: 0.021
# --------------------
# Epoch: 237, train loss: 0.021
# --------------------
# Epoch: 238, train loss: 0.02
# --------------------
# Epoch: 239, train loss: 0.02
# --------------------
# Epoch: 240, train loss: 0.02
# --------------------
# Epoch: 241, train loss: 0.02
# --------------------
# Epoch: 242, train loss: 0.019
# --------------------
# Epoch: 243, train loss: 0.019
# --------------------
# Epoch: 244, train loss: 0.019
# --------------------
# Epoch: 245, train loss: 0.019
# --------------------
# Epoch: 246, train loss: 0.018
# --------------------
# Epoch: 247, train loss: 0.018
# --------------------
# Epoch: 248, train loss: 0.018
# --------------------
# Epoch: 249, train loss: 0.018
# --------------------
# Epoch: 250, train loss: 0.017
# --------------------
# Epoch: 251, train loss: 0.017
# --------------------
# Epoch: 252, train loss: 0.017
# --------------------
# Epoch: 253, train loss: 0.017
# --------------------
# Epoch: 254, train loss: 0.017
# --------------------
# Epoch: 255, train loss: 0.016
# --------------------
# Epoch: 256, train loss: 0.016
# --------------------
# Epoch: 257, train loss: 0.016
# --------------------
# Epoch: 258, train loss: 0.016
# --------------------
# Epoch: 259, train loss: 0.016
# --------------------
# Epoch: 260, train loss: 0.016
# --------------------
# Epoch: 261, train loss: 0.015
# --------------------
# Epoch: 262, train loss: 0.015
# --------------------
# Epoch: 263, train loss: 0.015
# --------------------
# Epoch: 264, train loss: 0.015
# --------------------
# Epoch: 265, train loss: 0.015
# --------------------
# Epoch: 266, train loss: 0.014
# --------------------
# Epoch: 267, train loss: 0.014
# --------------------
# Epoch: 268, train loss: 0.014
# --------------------
# Epoch: 269, train loss: 0.014
# --------------------
# Epoch: 270, train loss: 0.014
# --------------------
# Epoch: 271, train loss: 0.014
# --------------------
# Epoch: 272, train loss: 0.014
# --------------------
# Epoch: 273, train loss: 0.013
# --------------------
# Epoch: 274, train loss: 0.013
# --------------------
# Epoch: 275, train loss: 0.013
# --------------------
# Epoch: 276, train loss: 0.013
# --------------------
# Epoch: 277, train loss: 0.013
# --------------------
# Epoch: 278, train loss: 0.013
# --------------------
# Epoch: 279, train loss: 0.013
# --------------------
# Epoch: 280, train loss: 0.012
# --------------------
# Epoch: 281, train loss: 0.012
# --------------------
# Epoch: 282, train loss: 0.012
# --------------------
# Epoch: 283, train loss: 0.012
# --------------------
# Epoch: 284, train loss: 0.012
# --------------------
# Epoch: 285, train loss: 0.012
# --------------------
# Epoch: 286, train loss: 0.012
# --------------------
# Epoch: 287, train loss: 0.012
# --------------------
# Epoch: 288, train loss: 0.012
# --------------------
# Epoch: 289, train loss: 0.011
# --------------------
# Epoch: 290, train loss: 0.011
# --------------------
# Epoch: 291, train loss: 0.011
# --------------------
# Epoch: 292, train loss: 0.011
# --------------------
# Epoch: 293, train loss: 0.011
# --------------------
# Epoch: 294, train loss: 0.011
# --------------------
# Epoch: 295, train loss: 0.011
# --------------------
# Epoch: 296, train loss: 0.011
# --------------------
# Epoch: 297, train loss: 0.011
# --------------------
# Epoch: 298, train loss: 0.01
# --------------------
# Epoch: 299, train loss: 0.01
# --------------------
# Epoch: 300, train loss: 0.01
# --------------------
# Epoch: 301, train loss: 0.01
# --------------------
# Epoch: 302, train loss: 0.01
# --------------------
# Epoch: 303, train loss: 0.01
# --------------------
# Epoch: 304, train loss: 0.01
# --------------------
# Epoch: 305, train loss: 0.01
# --------------------
# Epoch: 306, train loss: 0.01
# --------------------
# Epoch: 307, train loss: 0.01
# --------------------
# Epoch: 308, train loss: 0.01
# --------------------
# Epoch: 309, train loss: 0.009
# --------------------
# Epoch: 310, train loss: 0.009
# --------------------
# Epoch: 311, train loss: 0.009
# --------------------
# Epoch: 312, train loss: 0.009
# --------------------
# Epoch: 313, train loss: 0.009
# --------------------
# Epoch: 314, train loss: 0.009
# --------------------
# Epoch: 315, train loss: 0.009
# --------------------
# Epoch: 316, train loss: 0.009
# --------------------
# Epoch: 317, train loss: 0.009
# --------------------
# Epoch: 318, train loss: 0.009
# --------------------
# Epoch: 319, train loss: 0.009
# --------------------
# Epoch: 320, train loss: 0.009
# --------------------
# Epoch: 321, train loss: 0.009
# --------------------
# Epoch: 322, train loss: 0.009
# --------------------
# Epoch: 323, train loss: 0.008
# --------------------
# Epoch: 324, train loss: 0.008
# --------------------
# Epoch: 325, train loss: 0.008
# --------------------
# Epoch: 326, train loss: 0.008
# --------------------
# Epoch: 327, train loss: 0.008
# --------------------
# Epoch: 328, train loss: 0.008
# --------------------
# Epoch: 329, train loss: 0.008
# --------------------
# Epoch: 330, train loss: 0.008
# --------------------
# Epoch: 331, train loss: 0.008
# --------------------
# Epoch: 332, train loss: 0.008
# --------------------
# Epoch: 333, train loss: 0.008
# --------------------
# Epoch: 334, train loss: 0.008
# --------------------
# Epoch: 335, train loss: 0.008
# --------------------
# Epoch: 336, train loss: 0.008
# --------------------
# Epoch: 337, train loss: 0.008
# --------------------
# Epoch: 338, train loss: 0.008
# --------------------
# Epoch: 339, train loss: 0.007
# --------------------
# Epoch: 340, train loss: 0.007
# --------------------
# Epoch: 341, train loss: 0.007
# --------------------
# Epoch: 342, train loss: 0.007
# --------------------
# Epoch: 343, train loss: 0.007
# --------------------
# Epoch: 344, train loss: 0.007
# --------------------
# Epoch: 345, train loss: 0.007
# --------------------
# Epoch: 346, train loss: 0.007
# --------------------
# Epoch: 347, train loss: 0.007
# --------------------
# Epoch: 348, train loss: 0.007
# --------------------
# Epoch: 349, train loss: 0.007
# --------------------
# Epoch: 350, train loss: 0.007
# --------------------
# Epoch: 351, train loss: 0.007
# --------------------
# Epoch: 352, train loss: 0.007
# --------------------
# Epoch: 353, train loss: 0.007
# --------------------
# Epoch: 354, train loss: 0.007
# --------------------
# Epoch: 355, train loss: 0.007
# --------------------
# Epoch: 356, train loss: 0.007
# --------------------
# Epoch: 357, train loss: 0.007
# --------------------
# Epoch: 358, train loss: 0.006
# --------------------
# Epoch: 359, train loss: 0.006
# --------------------
# Epoch: 360, train loss: 0.006
# --------------------
# Epoch: 361, train loss: 0.006
# --------------------
# Epoch: 362, train loss: 0.006
# --------------------
# Epoch: 363, train loss: 0.006
# --------------------
# Epoch: 364, train loss: 0.006
# --------------------
# Epoch: 365, train loss: 0.006
# --------------------
# Epoch: 366, train loss: 0.006
# --------------------
# Epoch: 367, train loss: 0.006
# --------------------
# Epoch: 368, train loss: 0.006
# --------------------
# Epoch: 369, train loss: 0.006
# --------------------
# Epoch: 370, train loss: 0.006
# --------------------
# Epoch: 371, train loss: 0.006
# --------------------
# Epoch: 372, train loss: 0.006
# --------------------
# Epoch: 373, train loss: 0.006
# --------------------
# Epoch: 374, train loss: 0.006
# --------------------
# Epoch: 375, train loss: 0.006
# --------------------
# Epoch: 376, train loss: 0.006
# --------------------
# Epoch: 377, train loss: 0.006
# --------------------
# Epoch: 378, train loss: 0.006
# --------------------
# Epoch: 379, train loss: 0.006
# --------------------
# Epoch: 380, train loss: 0.006
# --------------------
# Epoch: 381, train loss: 0.006
# --------------------
# Epoch: 382, train loss: 0.006
# --------------------
# Epoch: 383, train loss: 0.005
# --------------------
# Epoch: 384, train loss: 0.005
# --------------------
# Epoch: 385, train loss: 0.005
# --------------------
# Epoch: 386, train loss: 0.005
# --------------------
# Epoch: 387, train loss: 0.005
# --------------------
# Epoch: 388, train loss: 0.005
# --------------------
# Epoch: 389, train loss: 0.005
# --------------------
# Epoch: 390, train loss: 0.005
# --------------------
# Epoch: 391, train loss: 0.005
# --------------------
# Epoch: 392, train loss: 0.005
# --------------------
# Epoch: 393, train loss: 0.005
# --------------------
# Epoch: 394, train loss: 0.005
# --------------------
# Epoch: 395, train loss: 0.005
# --------------------
# Epoch: 396, train loss: 0.005
# --------------------
# Epoch: 397, train loss: 0.005
# --------------------
# Epoch: 398, train loss: 0.005
# --------------------
# Epoch: 399, train loss: 0.005
# --------------------
# Epoch: 400, train loss: 0.005
# --------------------

# %%
x = torch.tensor([1.], requires_grad=True)
for _ in range(2):
    loss=x**2
    loss.backward()
    print(x.grad)    # if you use loss.backward() without The functions below, the result would be stacked by addition.  
    x.grad = None    # x.grad = 0 doesn't work
# Out:
# tensor([2.])
# tensor([2.])

# %%
print(F.binary_cross_entropy(y_hat, y))
print(-torch.sum(torch.log(y_hat**y*(1-y_hat)**(1-y)))/N)
# Out:
# tensor(0.0049, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0049, grad_fn=<DivBackward0>)

# %%
plt.plot(loss_history)
plt.xlabel('Epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## STEP 4. Model Test

# %%
x1_test = torch.linspace(-10,10,30) # case 1
x2_test = torch.linspace(-10,10,30) # case 2
X1_test, X2_test = torch.meshgrid(x1_test, x2_test)
X_test = torch.cat([X1_test.unsqueeze(dim=2), X2_test.unsqueeze(dim=2)], dim=2)


model.eval()      # change into test mode 
with torch.no_grad():
    y_hat = model(X_test)
# 1. Train mode and Test mode in Dropout or BN have quite different operation! so you should use eval() function!
# 2. Calculate grad_fn <- it is unnecessary!

Y_hat = y_hat.squeeze()

plt.figure(figsize=[10, 9])  # figsize=[가로, 세로]
ax = plt.axes(projection='3d')
ax.view_init(elev=25,azim=-140)
ax.plot_surface(X1_test, X2_test, Y_hat.numpy(), cmap='viridis', alpha=0.2)
plt.plot(class1_data[:,0],class1_data[:,1],class1_label.squeeze(),'bo')
plt.plot(class2_data[:,0],class2_data[:,1],class2_label.squeeze(),'ro')
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# Text(0.5, 0.5, 'x2')
