# %%
import torch

# %% [markdown]
# ## STEP 1. Make data

# %%
# case 1
N = 20
random0 = torch.randn(int(N/2), 1)
random5 = torch.randn(int(N/2), 1) + 5
class1_data = torch.hstack([random0, random5])
class2_data = torch.hstack([random5, random0])

class1_label = torch.ones(int(N/2),1)
class2_label = torch.zeros(int(N/2),1)
x = torch.vstack([class1_data, class2_data])
y = torch.vstack([class1_label, class2_label])
print(x.shape)
# Out:
# torch.Size([20, 2])

# %%
import matplotlib.pyplot as plt
plt.plot(class1_data[:,0], class1_data[:,1], 'o')
plt.plot(class2_data[:,0], class2_data[:,1], 'ro')
plt.xlabel('x1')
plt.ylabel('y1')
plt.grid()

# %% [markdown]
# ## STEP2. Make Model

# %%
from torch import nn

class MLP(nn.Module):
    def __init__(self):
        super().__init__()

        
        # case 1, plain
        self.linear = nn.Sequential(nn.Linear(2, 100),
                                    nn.Sigmoid(),
                                    nn.Linear(100, 1),
                                    nn.Sigmoid())

    
    def forward(self, x):
        x = self.linear(x)
        return x

# %%
model = MLP()
print(model)
# Out:
# MLP(
#   (linear): Sequential(
#     (0): Linear(in_features=2, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %% [markdown]
# ## STEP 3. Training Model

# %%
from torch import optim
import torch.nn.functional as F

LR = 1e-1 # case 1
EPOCH = 100 # case 2

optimizer  = optim.SGD(model.parameters(), lr=LR)

loss_history = []

model.train() # change into train mode
for it in range(EPOCH):
    # inference
    y_hat = model(x)
    # loss
    loss = F.binary_cross_entropy(y_hat, y) # y_hat(prediction) should be in front of y(target) ==> (y_hat, y)
    # update
    optimizer.zero_grad() # Prevent stack of gradient
    loss.backward()       # BPP(Back Propagation)
    optimizer.step()      # Weight update
    # print loss
    loss_history += [loss.item()]
    print(f'Epoch: {it+1}, train loss: {round(loss.item(),3)}')
    print('-'*20)
# Out:
# Epoch: 1, train loss: 0.59
# --------------------
# Epoch: 2, train loss: 0.486
# --------------------
# Epoch: 3, train loss: 0.41
# --------------------
# Epoch: 4, train loss: 0.353
# --------------------
# Epoch: 5, train loss: 0.309
# --------------------
# Epoch: 6, train loss: 0.274
# --------------------
# Epoch: 7, train loss: 0.246
# --------------------
# Epoch: 8, train loss: 0.222
# --------------------
# Epoch: 9, train loss: 0.203
# --------------------
# Epoch: 10, train loss: 0.187
# --------------------
# Epoch: 11, train loss: 0.173
# --------------------
# Epoch: 12, train loss: 0.161
# --------------------
# Epoch: 13, train loss: 0.15
# --------------------
# Epoch: 14, train loss: 0.141
# --------------------
# Epoch: 15, train loss: 0.132
# --------------------
# Epoch: 16, train loss: 0.125
# --------------------
# Epoch: 17, train loss: 0.119
# --------------------
# Epoch: 18, train loss: 0.113
# --------------------
# Epoch: 19, train loss: 0.107
# --------------------
# Epoch: 20, train loss: 0.102
# --------------------
# Epoch: 21, train loss: 0.098
# --------------------
# Epoch: 22, train loss: 0.094
# --------------------
# Epoch: 23, train loss: 0.09
# --------------------
# Epoch: 24, train loss: 0.086
# --------------------
# Epoch: 25, train loss: 0.083
# --------------------
# Epoch: 26, train loss: 0.08
# --------------------
# Epoch: 27, train loss: 0.077
# --------------------
# Epoch: 28, train loss: 0.075
# --------------------
# Epoch: 29, train loss: 0.072
# --------------------
# Epoch: 30, train loss: 0.07
# --------------------
# Epoch: 31, train loss: 0.068
# --------------------
# Epoch: 32, train loss: 0.066
# --------------------
# Epoch: 33, train loss: 0.064
# --------------------
# Epoch: 34, train loss: 0.062
# --------------------
# Epoch: 35, train loss: 0.06
# --------------------
# Epoch: 36, train loss: 0.059
# --------------------
# Epoch: 37, train loss: 0.057
# --------------------
# Epoch: 38, train loss: 0.056
# --------------------
# Epoch: 39, train loss: 0.054
# --------------------
# Epoch: 40, train loss: 0.053
# --------------------
# Epoch: 41, train loss: 0.052
# --------------------
# Epoch: 42, train loss: 0.05
# --------------------
# Epoch: 43, train loss: 0.049
# --------------------
# Epoch: 44, train loss: 0.048
# --------------------
# Epoch: 45, train loss: 0.047
# --------------------
# Epoch: 46, train loss: 0.046
# --------------------
# Epoch: 47, train loss: 0.045
# --------------------
# Epoch: 48, train loss: 0.044
# --------------------
# Epoch: 49, train loss: 0.043
# --------------------
# Epoch: 50, train loss: 0.043
# --------------------
# Epoch: 51, train loss: 0.042
# --------------------
# Epoch: 52, train loss: 0.041
# --------------------
# Epoch: 53, train loss: 0.04
# --------------------
# Epoch: 54, train loss: 0.039
# --------------------
# Epoch: 55, train loss: 0.039
# --------------------
# Epoch: 56, train loss: 0.038
# --------------------
# Epoch: 57, train loss: 0.037
# --------------------
# Epoch: 58, train loss: 0.037
# --------------------
# Epoch: 59, train loss: 0.036
# --------------------
# Epoch: 60, train loss: 0.035
# --------------------
# Epoch: 61, train loss: 0.035
# --------------------
# Epoch: 62, train loss: 0.034
# --------------------
# Epoch: 63, train loss: 0.034
# --------------------
# Epoch: 64, train loss: 0.033
# --------------------
# Epoch: 65, train loss: 0.033
# --------------------
# Epoch: 66, train loss: 0.032
# --------------------
# Epoch: 67, train loss: 0.032
# --------------------
# Epoch: 68, train loss: 0.031
# --------------------
# Epoch: 69, train loss: 0.031
# --------------------
# Epoch: 70, train loss: 0.03
# --------------------
# Epoch: 71, train loss: 0.03
# --------------------
# Epoch: 72, train loss: 0.03
# --------------------
# Epoch: 73, train loss: 0.029
# --------------------
# Epoch: 74, train loss: 0.029
# --------------------
# Epoch: 75, train loss: 0.028
# --------------------
# Epoch: 76, train loss: 0.028
# --------------------
# Epoch: 77, train loss: 0.028
# --------------------
# Epoch: 78, train loss: 0.027
# --------------------
# Epoch: 79, train loss: 0.027
# --------------------
# Epoch: 80, train loss: 0.027
# --------------------
# Epoch: 81, train loss: 0.026
# --------------------
# Epoch: 82, train loss: 0.026
# --------------------
# Epoch: 83, train loss: 0.026
# --------------------
# Epoch: 84, train loss: 0.025
# --------------------
# Epoch: 85, train loss: 0.025
# --------------------
# Epoch: 86, train loss: 0.025
# --------------------
# Epoch: 87, train loss: 0.024
# --------------------
# Epoch: 88, train loss: 0.024
# --------------------
# Epoch: 89, train loss: 0.024
# --------------------
# Epoch: 90, train loss: 0.024
# --------------------
# Epoch: 91, train loss: 0.023
# --------------------
# Epoch: 92, train loss: 0.023
# --------------------
# Epoch: 93, train loss: 0.023
# --------------------
# Epoch: 94, train loss: 0.023
# --------------------
# Epoch: 95, train loss: 0.022
# --------------------
# Epoch: 96, train loss: 0.022
# --------------------
# Epoch: 97, train loss: 0.022
# --------------------
# Epoch: 98, train loss: 0.022
# --------------------
# Epoch: 99, train loss: 0.021
# --------------------
# Epoch: 100, train loss: 0.021
# --------------------

# %%
x = torch.tensor([1.], requires_grad=True)
for _ in range(2):
    loss=x**2
    loss.backward()
    print(x.grad)    # if you use loss.backward() without The functions below, the result would be stacked by addition.  
    x.grad = None    # x.grad = 0 doesn't work
# Out:
# tensor([2.])
# tensor([2.])

# %%
print(F.binary_cross_entropy(y_hat, y))
print(-torch.sum(torch.log(y_hat**y*(1-y_hat)**(1-y)))/N)
# Out:
# tensor(0.0211, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0211, grad_fn=<DivBackward0>)

# %%
plt.plot(loss_history)
plt.xlabel('Epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## STEP 4. Model Test

# %%
x1_test = torch.linspace(-10,10,30) # case 1
x2_test = torch.linspace(-10,10,30) # case 2
X1_test, X2_test = torch.meshgrid(x1_test, x2_test)
X_test = torch.cat([X1_test.unsqueeze(dim=2), X2_test.unsqueeze(dim=2)], dim=2)


model.eval()      # change into test mode 
with torch.no_grad():
    y_hat = model(X_test)
# 1. Train mode and Test mode in Dropout or BN have quite different operation! so you should use eval() function!
# 2. Calculate grad_fn <- it is unnecessary!

Y_hat = y_hat.squeeze()

plt.figure(figsize=[10, 9])  # figsize=[가로, 세로]
ax = plt.axes(projection='3d')
ax.view_init(elev=25,azim=-140)
ax.plot_surface(X1_test, X2_test, Y_hat.numpy(), cmap='viridis', alpha=0.2)
plt.plot(class1_data[:,0],class1_data[:,1],class1_label.squeeze(),'bo')
plt.plot(class2_data[:,0],class2_data[:,1],class2_label.squeeze(),'ro')
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# Text(0.5, 0.5, 'x2')
